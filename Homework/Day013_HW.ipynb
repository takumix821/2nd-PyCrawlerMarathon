# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.ptt.cc/bbs/Stock/index.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")

# %%
for d in soup.find_all(class_="title"):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('標題： ' + d.text)
        print('作者： ' + r.find(class_='article-meta-value').text)
        print('時間： ' + r.find_all(class_='article-meta-value')[-1].text)
    except:
        continue
# Out:
# 標題：
#
# 				[請益] 為什麼歐美金融業很慘我們的卻還很賺
#
#
# 作者： audi86 (我勃起了)
# 時間： Sat Apr  4 16:18:02 2020
# 標題：
#
# 				[新聞] 防疫再加碼 科技部電燈、飲水機都貼銅箔
#
#
# 作者： shuaikehan (樹蛙懶覺)
# 時間： Sat Apr  4 16:21:33 2020
# 標題：
#
# 				[請益] 親人過世股票疑問
#
#
# 作者： poterjan (好久沒見到老大了...)
# 時間： Sat Apr  4 16:48:00 2020
# 標題：
#
# 				[新聞] 台積電確診員工恢復良好 接觸30名員工週
#
#
# 作者： GETpoint (擲雷爆卦)
# 時間： Sat Apr  4 17:26:46 2020
# 標題：
#
# 				[新聞]又有變數？ 路透：OPEC+緊急會議可能延兩
#
#
# 作者： ilqgray (counting stars)
# 時間： Sat Apr  4 17:32:27 2020
# 標題：
#
# 				[新聞] 漢翔以IDF和F16V實績 爭取空軍C-130運輸
#
#
# 作者： Reewalker (報告饅頭班長不夠)
# 時間： Sat Apr  4 18:06:13 2020
# 標題：
#
# 				Re: [請益] 親人過世股票疑問
#
#
# 作者： adam11734 (adam11734)
# 時間： Sat Apr  4 18:30:10 2020
# 標題：
#
# 				[新聞] 振興酷碰券 家樂福、PChome等不能用
#
#
# 作者： clubbox (史上最強7788 )
# 時間： Sat Apr  4 18:45:21 2020
# 標題：
#
# 				Re: [請益]  街口油二
#
#
# 作者： rity (禮藏24年)
# 時間： Sat Apr  4 19:31:24 2020
# 標題：
#
# 				Re: [請益]  美國道瓊多空不明
#
#
# 作者： ZMittermeyer (ZM)
# 時間： Sat Apr  4 19:48:30 2020
# 標題：
#
# 				[其他] 元大S&P石油正2申訴流程
#
#
# 作者： makai0917 (mark)
# 時間： Sat Apr  4 19:51:04 2020
# 標題：
#
# 				Re: [新聞] 振興酷碰券 家樂福、PChome等不能用
#
#
# 作者： a15568 (玉米)
# 時間： Sat Apr  4 19:53:52 2020
# 標題：
#
# 				Re: [新聞]又有變數？ 路透：OPEC+緊急會議可能延兩
#
#
# 作者： sharkpops (T-Rex)
# 時間： Sat Apr  4 20:02:58 2020
# 標題：
#
# 				[新聞] 錦州銀行不良貸款率6.52% 欲賣1500億債權
#
#
# 作者： Su22 (裝配匠)
# 時間： Sat Apr  4 20:24:19 2020
# 標題：
#
# 				Re: [其他] 元大S&P石油正2申訴流程
#
#
# 作者： bota (llll)
# 時間： Sat Apr  4 20:30:26 2020
# 標題：
#
# 				Re: [請益]  美國道瓊多空不明
#
#
# 作者： Freighter (貨輪)
# 時間： Sat Apr  4 20:37:41 2020
# 標題：
#
# 				Re: [其他] 元大S&P石油正2申訴流程
#
#
# 作者： goodid520 (台灣意志唯1綠地)
# 時間： Sat Apr  4 20:40:19 2020
# 標題：
#
# 				[心得] 石油加油戰2之「沙俄逼宮」
#
#
# 作者： trouble04323 (拿錢笑哈哈)
# 時間： Sat Apr  4 21:34:40 2020
# 標題：
#
# 				[新聞]疫情衝擊 中國店鋪大批停業求轉讓醞釀倒閉
#
#
# 作者： Su22 (裝配匠)
# 時間： Sat Apr  4 21:47:48 2020
# 標題：
#
# 				[請益] 風電概念股 前景如何?
#
#
# 作者： epson5566 (ep)
# 時間： Sat Apr  4 22:01:59 2020
# 標題：
#
# 				[公告] 精華區導覽Q&A
#
#
# 作者： IanLi (IanLi)
# 時間： Sun Jan 25 23:18:20 2015
# 標題：
#
# 				[公告] Stock 板規V2.6             (2019/06/20)
#
#
# 標題：
#
# 				[公告] 版規修正
#
#
# 作者： noldorelf (屏東周渝民)
# 時間： Sat Mar 28 22:48:50 2020
# 標題：
#
# 				[閒聊] 2020/04/03 盤後閒聊 清明
#
#
# 作者： vendan5566 (阿文)
# 時間： Fri Apr  3 08:30:00 2020

# %%
posts = []
for d in soup.find_all(class_="title"):
    try:
        post = {}
        post['標題'] = d.text.replace('\t', '').replace('\n', '')
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        post['作者'] = r.find(class_='article-meta-value').text
        post['時間'] = r.find_all(class_='article-meta-value')[-1].text
        posts.append(post)
    except:
        continue

# %%
posts
# Out:
# [{'標題': '[請益] 為什麼歐美金融業很慘我們的卻還很賺',
#   '作者': 'audi86 (我勃起了)',
#   '時間': 'Sat Apr  4 16:18:02 2020'},
#  {'標題': '[新聞] 防疫再加碼 科技部電燈、飲水機都貼銅箔',
#   '作者': 'shuaikehan (樹蛙懶覺)',
#   '時間': 'Sat Apr  4 16:21:33 2020'},
#  {'標題': '[請益] 親人過世股票疑問',
#   '作者': 'poterjan (好久沒見到老大了...)',
#   '時間': 'Sat Apr  4 16:48:00 2020'},
#  {'標題': '[新聞] 台積電確診員工恢復良好 接觸30名員工週',
#   '作者': 'GETpoint (擲雷爆卦)',
#   '時間': 'Sat Apr  4 17:26:46 2020'},
#  {'標題': '[新聞]又有變數？ 路透：OPEC+緊急會議可能延兩',
#   '作者': 'ilqgray (counting stars)',
#   '時間': 'Sat Apr  4 17:32:27 2020'},
#  {'標題': '[新聞] 漢翔以IDF和F16V實績 爭取空軍C-130運輸',
#   '作者': 'Reewalker (報告饅頭班長不夠)',
#   '時間': 'Sat Apr  4 18:06:13 2020'},
#  {'標題': 'Re: [請益] 親人過世股票疑問',
#   '作者': 'adam11734 (adam11734)',
#   '時間': 'Sat Apr  4 18:30:10 2020'},
#  {'標題': '[新聞] 振興酷碰券 家樂福、PChome等不能用',
#   '作者': 'clubbox (史上最強7788 )',
#   '時間': 'Sat Apr  4 18:45:21 2020'},
#  {'標題': 'Re: [請益]  街口油二',
#   '作者': 'rity (禮藏24年)',
#   '時間': 'Sat Apr  4 19:31:24 2020'},
#  {'標題': 'Re: [請益]  美國道瓊多空不明',
#   '作者': 'ZMittermeyer (ZM)',
#   '時間': 'Sat Apr  4 19:48:30 2020'},
#  {'標題': '[其他] 元大S&P石油正2申訴流程',
#   '作者': 'makai0917 (mark)',
#   '時間': 'Sat Apr  4 19:51:04 2020'},
#  {'標題': 'Re: [新聞] 振興酷碰券 家樂福、PChome等不能用',
#   '作者': 'a15568 (玉米)',
#   '時間': 'Sat Apr  4 19:53:52 2020'},
#  {'標題': 'Re: [新聞]又有變數？ 路透：OPEC+緊急會議可能延兩',
#   '作者': 'sharkpops (T-Rex)',
#   '時間': 'Sat Apr  4 20:02:58 2020'},
#  {'標題': '[新聞] 錦州銀行不良貸款率6.52% 欲賣1500億債權',
#   '作者': 'Su22 (裝配匠)',
#   '時間': 'Sat Apr  4 20:24:19 2020'},
#  {'標題': 'Re: [其他] 元大S&P石油正2申訴流程',
#   '作者': 'bota (llll)',
#   '時間': 'Sat Apr  4 20:30:26 2020'},
#  {'標題': 'Re: [請益]  美國道瓊多空不明',
#   '作者': 'Freighter (貨輪)',
#   '時間': 'Sat Apr  4 20:37:41 2020'},
#  {'標題': 'Re: [其他] 元大S&P石油正2申訴流程',
#   '作者': 'goodid520 (台灣意志唯1綠地)',
#   '時間': 'Sat Apr  4 20:40:19 2020'},
#  {'標題': '[心得] 石油加油戰2之「沙俄逼宮」',
#   '作者': 'trouble04323 (拿錢笑哈哈)',
#   '時間': 'Sat Apr  4 21:34:40 2020'},
#  {'標題': '[新聞]疫情衝擊 中國店鋪大批停業求轉讓醞釀倒閉',
#   '作者': 'Su22 (裝配匠)',
#   '時間': 'Sat Apr  4 21:47:48 2020'},
#  {'標題': '[請益] 風電概念股 前景如何?',
#   '作者': 'epson5566 (ep)',
#   '時間': 'Sat Apr  4 22:01:59 2020'},
#  {'標題': '[公告] 精華區導覽Q&A',
#   '作者': 'IanLi (IanLi)',
#   '時間': 'Sun Jan 25 23:18:20 2015'},
#  {'標題': '[公告] 版規修正',
#   '作者': 'noldorelf (屏東周渝民)',
#   '時間': 'Sat Mar 28 22:48:50 2020'},
#  {'標題': '[閒聊] 2020/04/03 盤後閒聊 清明',
#   '作者': 'vendan5566 (阿文)',
#   '時間': 'Fri Apr  3 08:30:00 2020'}]

# %%
posts = sorted(posts, key= lambda k: k['時間'])

# %%
posts
# Out:
# [{'標題': '[閒聊] 2020/04/03 盤後閒聊 清明',
#   '作者': 'vendan5566 (阿文)',
#   '時間': 'Fri Apr  3 08:30:00 2020'},
#  {'標題': '[請益] 為什麼歐美金融業很慘我們的卻還很賺',
#   '作者': 'audi86 (我勃起了)',
#   '時間': 'Sat Apr  4 16:18:02 2020'},
#  {'標題': '[新聞] 防疫再加碼 科技部電燈、飲水機都貼銅箔',
#   '作者': 'shuaikehan (樹蛙懶覺)',
#   '時間': 'Sat Apr  4 16:21:33 2020'},
#  {'標題': '[請益] 親人過世股票疑問',
#   '作者': 'poterjan (好久沒見到老大了...)',
#   '時間': 'Sat Apr  4 16:48:00 2020'},
#  {'標題': '[新聞] 台積電確診員工恢復良好 接觸30名員工週',
#   '作者': 'GETpoint (擲雷爆卦)',
#   '時間': 'Sat Apr  4 17:26:46 2020'},
#  {'標題': '[新聞]又有變數？ 路透：OPEC+緊急會議可能延兩',
#   '作者': 'ilqgray (counting stars)',
#   '時間': 'Sat Apr  4 17:32:27 2020'},
#  {'標題': '[新聞] 漢翔以IDF和F16V實績 爭取空軍C-130運輸',
#   '作者': 'Reewalker (報告饅頭班長不夠)',
#   '時間': 'Sat Apr  4 18:06:13 2020'},
#  {'標題': 'Re: [請益] 親人過世股票疑問',
#   '作者': 'adam11734 (adam11734)',
#   '時間': 'Sat Apr  4 18:30:10 2020'},
#  {'標題': '[新聞] 振興酷碰券 家樂福、PChome等不能用',
#   '作者': 'clubbox (史上最強7788 )',
#   '時間': 'Sat Apr  4 18:45:21 2020'},
#  {'標題': 'Re: [請益]  街口油二',
#   '作者': 'rity (禮藏24年)',
#   '時間': 'Sat Apr  4 19:31:24 2020'},
#  {'標題': 'Re: [請益]  美國道瓊多空不明',
#   '作者': 'ZMittermeyer (ZM)',
#   '時間': 'Sat Apr  4 19:48:30 2020'},
#  {'標題': '[其他] 元大S&P石油正2申訴流程',
#   '作者': 'makai0917 (mark)',
#   '時間': 'Sat Apr  4 19:51:04 2020'},
#  {'標題': 'Re: [新聞] 振興酷碰券 家樂福、PChome等不能用',
#   '作者': 'a15568 (玉米)',
#   '時間': 'Sat Apr  4 19:53:52 2020'},
#  {'標題': 'Re: [新聞]又有變數？ 路透：OPEC+緊急會議可能延兩',
#   '作者': 'sharkpops (T-Rex)',
#   '時間': 'Sat Apr  4 20:02:58 2020'},
#  {'標題': '[新聞] 錦州銀行不良貸款率6.52% 欲賣1500億債權',
#   '作者': 'Su22 (裝配匠)',
#   '時間': 'Sat Apr  4 20:24:19 2020'},
#  {'標題': 'Re: [其他] 元大S&P石油正2申訴流程',
#   '作者': 'bota (llll)',
#   '時間': 'Sat Apr  4 20:30:26 2020'},
#  {'標題': 'Re: [請益]  美國道瓊多空不明',
#   '作者': 'Freighter (貨輪)',
#   '時間': 'Sat Apr  4 20:37:41 2020'},
#  {'標題': 'Re: [其他] 元大S&P石油正2申訴流程',
#   '作者': 'goodid520 (台灣意志唯1綠地)',
#   '時間': 'Sat Apr  4 20:40:19 2020'},
#  {'標題': '[心得] 石油加油戰2之「沙俄逼宮」',
#   '作者': 'trouble04323 (拿錢笑哈哈)',
#   '時間': 'Sat Apr  4 21:34:40 2020'},
#  {'標題': '[新聞]疫情衝擊 中國店鋪大批停業求轉讓醞釀倒閉',
#   '作者': 'Su22 (裝配匠)',
#   '時間': 'Sat Apr  4 21:47:48 2020'},
#  {'標題': '[請益] 風電概念股 前景如何?',
#   '作者': 'epson5566 (ep)',
#   '時間': 'Sat Apr  4 22:01:59 2020'},
#  {'標題': '[公告] 版規修正',
#   '作者': 'noldorelf (屏東周渝民)',
#   '時間': 'Sat Mar 28 22:48:50 2020'},
#  {'標題': '[公告] 精華區導覽Q&A',
#   '作者': 'IanLi (IanLi)',
#   '時間': 'Sun Jan 25 23:18:20 2015'}]

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
r = requests.get(url, cookies={'over18': '1'})
soup = BeautifulSoup(r.text, "html5lib")

# %%
posts = []
for d in soup.find_all(class_="title"):
    try:
        post = {}
        post['標題'] = d.text.replace('\t', '').replace('\n', '')
        
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href'], cookies={'over18': '1'}).text, "html5lib")
        post['作者'] = r.find(class_='article-meta-value').text
        post['時間'] = r.find_all(class_='article-meta-value')[-1].text
        posts.append(post)
    except:
        continue

# %%
posts = sorted(posts, key= lambda x: x['時間'])

# %%
posts
# Out:
# [{'標題': '[新聞] 清明連假搭客運 桃園景點交通好康報你知!',
#   '作者': 'cliffcliff (號：)',
#   '時間': 'Sat Apr  4 22:12:38 2020'},
#  {'標題': 'Re: [問卦] 新竹跟高雄哪個才是美食沙漠？',
#   '作者': 'redDest (油油)',
#   '時間': 'Sat Apr  4 22:13:09 2020'},
#  {'標題': 'Re: [問卦] 守靈有點哀傷的正妹，請問要怎麼撫慰他',
#   '作者': 'cwh0105 (Ex咖哩棒)',
#   '時間': 'Sat Apr  4 22:13:14 2020'},
#  {'標題': 'Re: [爆卦] STEAM慘遭祖國舉報違反禁娛哀悼令',
#   '作者': 'laptic (靜夜聖林彼岸花)',
#   '時間': 'Sat Apr  4 22:13:57 2020'},
#  {'標題': 'Re: [政治] 紓困預算再追加總額逾1兆\u3000蔣萬安籲︰每人發現金5千至1',
#   '作者': 'greedyba ()',
#   '時間': 'Sat Apr  4 22:14:54 2020'},
#  {'標題': '[問卦] 有國賓飯店500元便當的卦嗎',
#   '作者': 'winogu (win)',
#   '時間': 'Sat Apr  4 22:15:13 2020'},
#  {'標題': '[問卦] 校園民歌年代最經典的要選哪幾首？？',
#   '作者': 'doasgloria (青柳立夏)',
#   '時間': 'Sat Apr  4 22:15:13 2020'},
#  {'標題': 'Re: [問卦] 基努李維的狗 連恩尼遜的女兒',
#   '作者': 'chucky (衛藤x白石x橋本)',
#   '時間': 'Sat Apr  4 22:15:33 2020'},
#  {'標題': 'Re: [問卦] 基努李維的狗 連恩尼遜的女兒',
#   '作者': 'senma (ライフ☆ライン)',
#   '時間': 'Sat Apr  4 22:15:37 2020'},
#  {'標題': '[問卦] 什麼微波食品是711之王',
#   '作者': 'jwlhs104 (機智小字典)',
#   '時間': 'Sat Apr  4 22:16:10 2020'},
#  {'標題': '[問卦] 很想拿到消費券是正常的嗎？',
#   '作者': 'soulboy330 (stay the course)',
#   '時間': 'Sat Apr  4 22:16:10 2020'},
#  {'標題': '[問卦] 人性實驗',
#   '作者': 'god46 (大家好,我是JayJay林俊傑)',
#   '時間': 'Sat Apr  4 22:16:22 2020'},
#  {'標題': '[新聞] 武漢肺炎 中國下半旗悼犧牲者 趙立堅:來',
#   '作者': 'yor ()',
#   '時間': 'Sat Apr  4 22:17:09 2020'},
#  {'標題': '[問卦] 如果是肥宅懂我奇奇怪怪陪我可可愛愛的話',
#   '作者': "HDSM (Love Not Change  O'_'O)",
#   '時間': 'Sat Apr  4 22:17:30 2020'},
#  {'標題': '[問卦] 要怎麼轉職成德魯伊的八卦',
#   '作者': 'c753968412 (c753968412)',
#   '時間': 'Sat Apr  4 22:17:35 2020'},
#  {'標題': 'Re: [爆卦] 4月4日中共全國哀悼武漢肺炎，遊戲業亦同',
#   '作者': 'hoanbeh (初入江湖淨添堵)',
#   '時間': 'Sat Apr  4 22:18:11 2020'},
#  {'標題': '[公告] 八卦板板規(2020.03.21)',
#   '作者': 'DreamYeh (天使)',
#   '時間': 'Sat Mar 21 00:42:44 2020'},
#  {'標題': '[協尋] 走失失智老人協尋',
#   '作者': 'ayakaku (AYA)',
#   '時間': 'Thu Apr  2 14:33:54 2020'},
#  {'標題': '[協尋]  3/25  16點寶山路往食品路車禍影像',
#   '作者': 'funnyemma (飲料好難戒QQ)',
#   '時間': 'Thu Mar 26 14:14:37 2020'}]
