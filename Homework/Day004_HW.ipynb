# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11704244765","type":"PushEvent","actor":{"id":61901052,"login":"sandeep-sparrow","display_login":"sandeep-sparrow","gravatar_id":"","url":"https://api.github.com/users/sandeep-sparrow","avatar_url":"https://avatars.githubusercontent.com/u/61901052?"},"repo":{"id":245592111,"name":"sandeep-sparrow/hello-web-app","url":"https://api.github.com/repos/sandeep-sparrow/hello-web-app"},"payload":{"push_id":4732073924,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"8e49e0259857bbcb7aa29f83f5ed507832c3b708","before":"2654aff91a452fec46c8cbd2644094f70dcaf61a","commits":[{"sha":"8e49e0259857bbcb7aa29f83f5ed507832c3b708","author":{"email":"61901052+sandeep-sparrow@users.noreply.github.com","name":"Sandeep prajapati"},"message":"Add files via upload","distinct":true,"url":"https://api.github.com/repos/sandeep-sparrow/hello-web-app/commits/8e49e0259857bbcb7aa29f83f5ed507832c3b708"}]},"public":true,"created_at":"2020-03-07T08:07:36Z"},{"id":"11704244760","type":"PushEvent","act
# ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11704244765',
#   'type': 'PushEvent',
#   'actor': {'id': 61901052,
#    'login': 'sandeep-sparrow',
#    'display_login': 'sandeep-sparrow',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sandeep-sparrow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61901052?'},
#   'repo': {'id': 245592111,
#    'name': 'sandeep-sparrow/hello-web-app',
#    'url': 'https://api.github.com/repos/sandeep-sparrow/hello-web-app'},
#   'payload': {'push_id': 4732073924,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8e49e0259857bbcb7aa29f83f5ed507832c3b708',
#    'before': '2654aff91a452fec46c8cbd2644094f70dcaf61a',
#    'commits': [{'sha': '8e49e0259857bbcb7aa29f83f5ed507832c3b708',
#      'author': {'email': '61901052+sandeep-sparrow@users.noreply.github.com',
#       'name': 'Sandeep prajapati'},
#      'message': 'Add files via upload',
#      'distinct': True,
# ...

# %%
import requests

rwl= requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
rwl.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2200H029","WaterLevel": 145.15},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H070","WaterLevel": 226.25},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H021","WaterLevel": 1.28},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H017","WaterLevel": 25.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2560H019","WaterLevel": 4.48},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H001","WaterLevel": 224.21},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H075","WaterLevel": 92.83},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H036","WaterLevel": 164.37},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2500H003","WaterLevel": 32.2},{"RecordTime": "Dec 11, 2019 2:50:00 PM
# ...

# %%
import requests

rwl = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel', data = {'key1':'value1','key2':'value2','key3':'value3'})
json.loads(rwl.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': 145.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': 226.25},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.28},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': 4.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': 224.21},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': 92.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H036',
# ...
